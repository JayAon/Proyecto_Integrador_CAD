# %%
import pandas as pd
import numpy as np

file = "data/BASE DE DATOS PCC.xlsx"
df = pd.read_excel(file)
df.head(10)
# Out:
#    Pedido    OP     Referencia                                   Maquina  \
# 0   25301  6362  PT-0000001709  AMECPEGACA - Pegadora de Cajas Signature
# 1   25301  6362  PT-0000001709  AMECPEGACA - Pegadora de Cajas Signature
# 2   26146  7258  PT-0000000197  AMECPEGACA - Pegadora de Cajas Signature
# 3   26146  7258  PT-0000000197  AMECPEGACA - Pegadora de Cajas Signature
# 4   26550  7685  PT-0000001846  MAQSPEED - Maquina Speed master pliego 6
# 5   26550  7685  PT-0000001846  MAQSPEED - Maquina Speed master pliego 6
# 6   26589  7725  PT-0000000616  MAQSPEED - Maquina Speed master pliego 6
# 7   26589  7725  PT-0000000616  MAQSPEED - Maquina Speed master pliego 6
# 8   26589  7725  PT-0000000616  MAQSPEED - Maquina Speed master pliego 6
# 9   26589  7725  PT-0000000616  MAQSPEED - Maquina Speed master pliego 6
#
#              Sección     Proceso     Usuario Estado Fabricadas  \
# 0  Pegadora de Cajas       Pegar    dcardona   PLAY      12000
# 1  Pegadora de Cajas  cambiorefe    dcardona   STOP          0
# 2  Pegadora de Cajas       Pegar    dcardona   PLAY      28000
# 3  Pegadora de Cajas  cambiorefe    dcardona   STOP          0
# 4             Prensa    Imprimir      jhenao   PLAY      24660
# 5             Prensa  cambiorefe      jhenao   STOP          0
# 6             Prensa    Imprimir  cpiedrahit   PLAY       4200
# 7             Prensa    Imprimir  cpiedrahit   PLAY       3320
# 8             Prensa  cambiorefe  cpiedrahit   STOP          0
# 9             Prensa  cambiorefe  cpiedrahit   STOP          0
#
#           Fecha inicio            Fecha fin  Duración  Duración [min]  \
# 0  2024-01-28 12:07:29  2024-01-28 12:35:45  00:28:16           28.27
# 1  2024-01-28 11:49:01  2024-01-28 12:07:29  00:18:28           18.47
# 2  2024-01-29 07:29:18  2024-01-29 08:18:30  00:49:12           49.20
# 3  2024-01-29 06:53:59  2024-01-29 07:29:18  00:35:19           35.32
# 4  2023-08-24 00:15:33  2023-08-24 00:49:30  00:33:57           33.95
# 5  2023-08-24 00:11:56  2023-08-24 00:15:33  00:03:37            3.62
# 6  2023-08-28 00:31:58  2023-08-28 01:01:06  00:29:08           29.13
# 7  2023-08-28 01:56:18  2023-08-28 02:28:50  00:32:32           32.53
# 8  2023-08-27 22:41:15  2023-08-27 23:59:59  01:18:44           78.73
# 9  2023-08-28 00:00:00  2023-08-28 00:18:40  00:18:40           18.67
#
#   Ayudante  Info. Extra 1
# 0       No            NaN
# 1       No            NaN
# 2       No            NaN
# 3       No            NaN
# 4       No            6.0
# 5       No            6.0
# 6       No            2.0
# 7       No            2.0
# 8       No            2.0
# 9       No            2.0

# %%
# Información general
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23651 entries, 0 to 23650
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pedido          23651 non-null  int64
#  1   OP              23651 non-null  int64
#  2   Referencia      23651 non-null  object
#  3   Maquina         23651 non-null  object
#  4   Sección         23651 non-null  object
#  5   Proceso         23651 non-null  object
#  6   Usuario         23651 non-null  object
#  7   Estado          23651 non-null  object
#  8   Fabricadas      23651 non-null  object
#  9   Fecha inicio    23651 non-null  object
#  10  Fecha fin       23651 non-null  object
#  11  Duración        23651 non-null  object
#  12  Duración [min]  23649 non-null  float64
#  13  Ayudante        23651 non-null  object
#  14  Info. Extra 1   23590 non-null  float64
# dtypes: float64(2), int64(2), object(11)
# memory usage: 2.7+ MB

# %%
# Estadísticas básicas
df.describe(include='all').style.background_gradient(cmap = "plasma")
# Out:
# <style type="text/css">
# #T_381ab_row0_col0 {
#   background-color: #fa9b3d;
#   color: #000000;
# }
# #T_381ab_row0_col1, #T_381ab_row0_col8, #T_381ab_row0_col12, #T_381ab_row0_col14, #T_381ab_row10_col0 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_381ab_row1_col0, #T_381ab_row1_col1, #T_381ab_row1_col12, #T_381ab_row1_col14, #T_381ab_row2_col0, #T_381ab_row2_col1, #T_381ab_row2_col12, #T_381ab_row2_col14, #T_381ab_row3_col0, #T_381ab_row3_col1, #T_381ab_row3_col12, #T_381ab_row3_col14, #T_381ab_row4_col8, #T_381ab_row5_col8, #T_381ab_row6_col8, #T_381ab_row7_col8, #T_381ab_row8_col8, #T_381ab_row9_col8, #T_381ab_row10_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_381ab_row1_col8 {
#   background-color: #5b01a5;
#   color: #f1f1f1;
# }
# #T_381ab_row2_col8, #T_381ab_row4_col12, #T_381ab_row4_col14, #T_381ab_row5_col0, #T_381ab_row5_col1, #T_381ab_row5_col12, #T_381ab_row5_col14, #T_381ab_row6_col12, #T_381ab_row6_col14, #T_381ab_row7_col12, #T_381ab_row7_col14, #T_381ab_row8_col12, #T_381ab_row8_col14, #T_381ab_row9_col12, #T_381ab_row9_col14 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_381ab_row3_col8 {
#   background-color: #d9586a;
#   color: #f1f1f1;
# }
# #T_381ab_row4_col0 {
#   background-color: #f7e225;
#   color: #000000;
# }
# #T_381ab_row4_col1 {
#   background-color: #b52f8c;
#   color: #f1f1f1;
# }
# #T_381ab_row6_col0 {
#   background-color: #fdaf31;
#   color: #000000;
# }
# #T_381ab_row6_col1 {
#   background-color: #7a02a8;
#   color: #f1f1f1;
# }
# #T_381ab_row7_col0 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_381ab_row7_col1 {
#   background-color: #ae2892;
#   color: #f1f1f1;
# }
# #T_381ab_row8_col0 {
#   background-color: #f7e425;
#   color: #000000;
# }
# #T_381ab_row8_col1 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# #T_381ab_row9_col0 {
#   background-color: #f4ed27;
#   color: #000000;
# }
# #T_381ab_row9_col1 {
#   background-color: #be3885;
#   color: #f1f1f1;
# }
# #T_381ab_row10_col1 {
#   background-color: #c7427c;
#   color: #f1f1f1;
# }
# #T_381ab_row10_col12 {
#   background-color: #1b068d;
#   color: #f1f1f1;
# }
# #T_381ab_row10_col14 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_381ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_381ab_level0_col0" class="col_heading level0 col0" >Pedido</th>
#       <th id="T_381ab_level0_col1" class="col_heading level0 col1" >OP</th>
#       <th id="T_381ab_level0_col2" class="col_heading level0 col2" >Referencia</th>
#       <th id="T_381ab_level0_col3" class="col_heading level0 col3" >Maquina</th>
#       <th id="T_381ab_level0_col4" class="col_heading level0 col4" >Sección</th>
#       <th id="T_381ab_level0_col5" class="col_heading level0 col5" >Proceso</th>
#       <th id="T_381ab_level0_col6" class="col_heading level0 col6" >Usuario</th>
#       <th id="T_381ab_level0_col7" class="col_heading level0 col7" >Estado</th>
#       <th id="T_381ab_level0_col8" class="col_heading level0 col8" >Fabricadas</th>
#       <th id="T_381ab_level0_col9" class="col_heading level0 col9" >Fecha inicio</th>
#       <th id="T_381ab_level0_col10" class="col_heading level0 col10" >Fecha fin</th>
#       <th id="T_381ab_level0_col11" class="col_heading level0 col11" >Duración</th>
#       <th id="T_381ab_level0_col12" class="col_heading level0 col12" >Duración [min]</th>
#       <th id="T_381ab_level0_col13" class="col_heading level0 col13" >Ayudante</th>
#       <th id="T_381ab_level0_col14" class="col_heading level0 col14" >Info. Extra 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_381ab_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_381ab_row0_col0" class="data row0 col0" >23651.000000</td>
#       <td id="T_381ab_row0_col1" class="data row0 col1" >23651.000000</td>
#       <td id="T_381ab_row0_col2" class="data row0 col2" >23651</td>
#       <td id="T_381ab_row0_col3" class="data row0 col3" >23651</td>
#       <td id="T_381ab_row0_col4" class="data row0 col4" >23651</td>
#       <td id="T_381ab_row0_col5" class="data row0 col5" >23651</td>
#       <td id="T_381ab_row0_col6" class="data row0 col6" >23651</td>
#       <td id="T_381ab_row0_col7" class="data row0 col7" >23651</td>
#       <td id="T_381ab_row0_col8" class="data row0 col8" >23651.000000</td>
#       <td id="T_381ab_row0_col9" class="data row0 col9" >23651</td>
#       <td id="T_381ab_row0_col10" class="data row0 col10" >23651</td>
#       <td id="T_381ab_row0_col11" class="data row0 col11" >23651</td>
#       <td id="T_381ab_row0_col12" class="data row0 col12" >23649.000000</td>
#       <td id="T_381ab_row0_col13" class="data row0 col13" >23651</td>
#       <td id="T_381ab_row0_col14" class="data row0 col14" >23590.000000</td>
#     </tr>
#     <tr>
#       <th id="T_381ab_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_381ab_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_381ab_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_381ab_row1_col2" class="data row1 col2" >842</td>
#       <td id="T_381ab_row1_col3" class="data row1 col3" >13</td>
#       <td id="T_381ab_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_381ab_row1_col5" class="data row1 col5" >17</td>
#       <td id="T_381ab_row1_col6" class="data row1 col6" >34</td>
#       <td id="T_381ab_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_381ab_row1_col8" class="data row1 col8" >3820.000000</td>
#       <td id="T_381ab_row1_col9" class="data row1 col9" >23131</td>
#       <td id="T_381ab_row1_col10" class="data row1 col10" >23125</td>
#       <td id="T_381ab_row1_col11" class="data row1 col11" >9062</td>
#       <td id="T_381ab_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_381ab_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_381ab_row1_col14" class="data row1 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_381ab_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_381ab_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_381ab_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_381ab_row2_col2" class="data row2 col2" >PT-0000001912</td>
#       <td id="T_381ab_row2_col3" class="data row2 col3" >MAQSPEED - Maquina Speed master pliego 6</td>
#       <td id="T_381ab_row2_col4" class="data row2 col4" >Prensa</td>
#       <td id="T_381ab_row2_col5" class="data row2 col5" >cambiorefe</td>
#       <td id="T_381ab_row2_col6" class="data row2 col6" >mmartinez</td>
#       <td id="T_381ab_row2_col7" class="data row2 col7" >PLAY</td>
#       <td id="T_381ab_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_381ab_row2_col9" class="data row2 col9" >2024-10-31 00:00:00</td>
#       <td id="T_381ab_row2_col10" class="data row2 col10" >2024-10-08 23:59:59</td>
#       <td id="T_381ab_row2_col11" class="data row2 col11" >00:00:08</td>
#       <td id="T_381ab_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_381ab_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_381ab_row2_col14" class="data row2 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_381ab_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_381ab_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_381ab_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_381ab_row3_col2" class="data row3 col2" >660</td>
#       <td id="T_381ab_row3_col3" class="data row3 col3" >5505</td>
#       <td id="T_381ab_row3_col4" class="data row3 col4" >11154</td>
#       <td id="T_381ab_row3_col5" class="data row3 col5" >9619</td>
#       <td id="T_381ab_row3_col6" class="data row3 col6" >1389</td>
#       <td id="T_381ab_row3_col7" class="data row3 col7" >13851</td>
#       <td id="T_381ab_row3_col8" class="data row3 col8" >13235.000000</td>
#       <td id="T_381ab_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_381ab_row3_col10" class="data row3 col10" >5</td>
#       <td id="T_381ab_row3_col11" class="data row3 col11" >52</td>
#       <td id="T_381ab_row3_col12" class="data row3 col12" >nan</td>
#       <td id="T_381ab_row3_col13" class="data row3 col13" >23651</td>
#       <td id="T_381ab_row3_col

# %%
import unidecode
# Eliminar acentos
df.columns = [unidecode.unidecode(col) for col in df.columns]
# Quitar espacios y estandarizar nombres de columnas
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.columns = df.columns.str.strip().str.lower().str.replace('.', '')
df.columns = df.columns.str.strip().str.lower().str.replace('[', '')
df.columns = df.columns.str.strip().str.lower().str.replace(']', '')
print(df.columns)
# Out:
# Index(['pedido', 'op', 'referencia', 'maquina', 'seccion', 'proceso',
#        'usuario', 'estado', 'fabricadas', 'fecha_inicio', 'fecha_fin',
#        'duracion', 'duracion_min', 'ayudante', 'info_extra_1'],
#       dtype='object')

# %%
# Valores nulos
print(df.isnull().sum())

# Registros duplicados
print(f"Duplicados: {df.duplicated().sum()}")
# Out:
# pedido           0
# op               0
# referencia       0
# maquina          0
# seccion          0
# proceso          0
# usuario          0
# estado           0
# fabricadas       0
# fecha_inicio     0
# fecha_fin        0
# duracion         0
# duracion_min     2
# ayudante         0
# info_extra_1    61
# dtype: int64
# Duplicados: 0

# %%
#Verificar por posibles variantes sin variacion
single_unique = df.nunique()
single_unique
# Out:
# pedido           3092
# op               3128
# referencia        842
# maquina            13
# seccion             3
# proceso            17
# usuario            34
# estado              2
# fabricadas       3820
# fecha_inicio    23131
# fecha_fin       23125
# duracion         9062
# duracion_min     9117
# ayudante            1
# info_extra_1       42
# dtype: int64

# %%
# Cambiar el tipo de variable de fabricadas
df['fabricadas'] = pd.to_numeric(df['fabricadas'], errors='coerce')
# Tipo de variable datetime
df['fecha_inicio'] = pd.to_datetime(df['fecha_inicio'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df['fecha_fin'] = pd.to_datetime(df['fecha_fin'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
# Variables de fecha adicionales
df['dia_inicio'] = df['fecha_inicio'].dt.date
df['hora_inicio'] = df['fecha_inicio'].dt.hour
df['dia_semana_inicio'] = df['fecha_inicio'].dt.day_name()

# %%
df['dia_fin'] = df['fecha_fin'].dt.date
df['hora_fin'] = df['fecha_fin'].dt.hour
df['dia_semana_fin'] = df['fecha_fin'].dt.day_name()

# %%
df['duracion'] = pd.to_timedelta(df['duracion'])
df['duracion'] = df['duracion'].dt.total_seconds()
#Cambiar nombre de la columna
df.rename(columns={'duracion': 'duracion_sec'}, inplace=True)

# %%
errores = df[df['fecha_fin'] < df['fecha_inicio']]
print(f"Registros con fechas invertidas: {len(errores)}")
# Out:
# Registros con fechas invertidas: 0

# %%
#Eliminar columnas innecesarias
df.drop(columns=['ayudante','info_extra_1'], inplace=True)

df['estado'] = df['estado'].str.strip().str.lower()
#Eliminar filas con estado "play" sin produccion o producción NAN (errores de digitacion)
df = df[~((df['estado'] == 'play') & (df['fabricadas'] == 0))]
df = df[~df['fabricadas'].isna()]
# Llenar valor nulos de duracion_minutos con el calculo de la diferencia entre fecha_inicio y fecha_fin
# Calcular diferencia en minutos
diferencia_min = (df['fecha_fin'] - df['fecha_inicio']).dt.total_seconds() / 60

# Solo llenar valores faltantes
df['duracion_min'] = df['duracion_min'].fillna(diferencia_min)

# %%
# Valores nulos
print(df.isnull().sum())
print("*"*50)
# Registros duplicados
print(f"Duplicados: {df.duplicated().sum()}")
print("*"*50)
#Verificar por posibles variantes sin variacion
single_unique = df.nunique()
print(single_unique)
# Out:
# pedido               0
# op                   0
# referencia           0
# maquina              0
# seccion              0
# proceso              0
# usuario              0
# estado               0
# fabricadas           0
# fecha_inicio         0
# fecha_fin            0
# duracion_sec         0
# duracion_min         0
# dia_inicio           0
# hora_inicio          0
# dia_semana_inicio    0
# dia_fin              0
# hora_fin             0
# dia_semana_fin       0
# dtype: int64
# **************************************************
# Duplicados: 0
# **************************************************
# pedido                3092
# op                    3128
# referencia             842
# maquina                 12
# seccion                  3
# proceso                 17
# usuario                 31
# estado                   2
# fabricadas            3819
# fecha_inicio         19832
# fecha_fin            20063
# duracion_sec          8350
# duracion_min          8401
# dia_inicio             486
# hora_inicio             24
# dia_semana_inicio        7
# dia_fin                486
# hora_fin                24
# dia_semana_fin           7
# dtype: int64

# %%
#Valores unicos en variables categóricas (HACER EN SQL)
# Sección, usuario, estado, máquina
print("Valores únicos por columna:")
for col in ['estado', 'usuario', 'seccion','maquina','proceso']:
    if col in df.columns:
        print(f"{col}: {df[col].unique()}")
        print(df[col].value_counts())
        print("-"*50)
# Out:
# Valores únicos por columna:
# estado: ['play' 'stop']
# estado
# play    10415
# stop     9800
# Name: count, dtype: int64
# --------------------------------------------------
# usuario: ['dcardona' 'jhenao' 'cpiedrahit' 'mmartinez' 'falzate' 'acalderon'
#  'hgranada' 'agomez' 'avalencia' 'jpatino' 'lmejia' 'jzapata' 'rvelasquez'
#  'aflorez' 'lvelasquez' 'bortega' 'nserna' 'aherrera' 'jcacevedo'
#  'jpalacio' 'jacevedo' 'cbarrientos' 'lechavarria' 'lsanchez' 'dgaviria'
#  'rsuarez' 'ezapata' 'dmoreno' 'ksolorza' 'mquiroz' 'bsuarez']
# usuario
# mmartinez      1354
# jcacevedo      1211
# lvelasquez     1204
# hgranada       1108
# aflorez        1100
# rvelasquez     1088
# jacevedo       1077
# cpiedrahit     1057
# aherrera       1035
# agomez         1024
# dcardona       1002
# falzate         935
# jzapata         817
# jhenao          794
# bortega         789
# nserna          753
# jpatino         732
# avalencia       729
# acalderon       611
# lmejia          510
# jpalacio        481
# dgaviria        200
# dmoreno         185
# cbarrientos     181
# mquiroz         114
# lechavarria     111
# ksolorza          4
# lsanchez          3
# ezapata           3
# bsuarez           2
# rsuarez           1
# Name: count, dtype: int64
# --------------------------------------------------
# seccion: ['Pegadora de Cajas' 'Prensa' 'Troquelado']
# seccion
# Prensa               9303
# Troquelado           6499
# Pegadora de Cajas    4413
# Name: count, dtype: int64
# --------------------------------------------------
# maquina: ['AMECPEGACA - Pegadora de Cajas Signature'
#  'MAQSPEED - Maquina Speed master pliego 6'
#  'MAQR700 - Maquina R700 6 color + barniz'
#  'AMECPEGACA2 - Pegadora de Cajas Nueva'
#  'BOBST102 - Troqueladora Bobst  102'
#  'BOBST1080 - Troqueladora Bobst 1080' 'INDIGO5500 - Indigo Hp 5500'
#  'MAQBICOLR - Maquina Roland Bicolor pliego'
#  'TROQ1/2 - Troqueladora de 1/2' 'TROQ1/4 - Troqueladora de 1/4'
#  'BANCOPREALISTAR1 - Bando de Prealistar 1'
#  'NOVACUT106 - Troqueladora NovaCut 106']
# maquina
# MAQR700 - Maquina R700 6 color + barniz      4370
# MAQSPEED - Maquina Speed master pliego 6     4336
# BOBST102 - Troqueladora Bobst  102           3544
# AMECPEGACA2 - Pegadora de Cajas Nueva        2230
# AMECPEGACA - Pegadora de Cajas Signature     2183
# BOBST1080 - Troqueladora Bobst 1080          2179
# TROQ1/2 - Troqueladora de 1/2                 627
# MAQBICOLR - Maquina Roland Bicolor pliego     416
# INDIGO5500 - Indigo Hp 5500                   181
# TROQ1/4 - Troqueladora de 1/4                  97
# NOVACUT106 - Troqueladora NovaCut 106          51
# BANCOPREALISTAR1 - Bando de Prealistar 1        1
# Name: count, dtype: int64
# --------------------------------------------------
# proceso: ['Pegar' 'cambiorefe' 'Imprimir' 'Barnizar' 'Imprimir 2' 'Troquelar'
#  'PreCortar' 'Grafar' '1LAVAR' 'LEVANTAR LIMPIAR MANTILLA' 'TROQUELAR2'
#  'Estampar' 'Brailer' 'Repujar' 'Barnizar UV' 'Barnizar UV + Mate'
#  'TROQUELAR1']
# proceso
# cambiorefe                   9619
# Imprimir                     4098
# Troquelar                    3395
# Pegar                        2371
# Barnizar                      234
# LEVANTAR LIMPIAR MANTILLA     118
# Imprimir 2                    110
# Brailer                        90
# 1LAVAR                         63
# Grafar                         30
# Barnizar UV + Mate             22
# Barnizar UV                    20
# PreCortar                      13
# TROQUELAR2                     12
# Repujar                         9
# TROQUELAR1                      7
# Estampar                        4
# Name: count, dtype: int64
# --------------------------------------------------

# %%
print("-"*50)
# Conteo general de estados
print(df['estado'].value_counts())
print("-"*50)
# Por usuario
print(df.groupby('usuario')['estado'].value_counts())
print("-"*50)
# Por sección
print(df.groupby('seccion')['estado'].value_counts())
print("-"*50)
# Por día
print("Dias de fabricación")
print("Inicio")
print(len(df.groupby('dia_inicio')['estado'].value_counts()))
print("Fin")
print(len(df.groupby('dia_fin')['estado'].value_counts()))
print("-"*50)
# Out:
# --------------------------------------------------
# estado
# play    10415
# stop     9800
# Name: count, dtype: int64
# --------------------------------------------------
# usuario      estado
# acalderon    stop      336
#              play      275
# aflorez      play      624
#              stop      476
# agomez       stop      518
#              play      506
# aherrera     play      553
#              stop      482
# avalencia    stop      385
#              play      344
# bortega      play      424
#              stop      365
# bsuarez      play        2
# cbarrientos  play      181
# cpiedrahit   stop      578
#              play      479
# dcardona     play      532
#              stop      470
# dgaviria     play      107
#              stop       93
# dmoreno      stop      100
#              play       85
# ezapata      play        3
# falzate      stop      582
#              play      353
# hgranada     stop      641
#              play      467
# jacevedo     stop      541
#              play      536
# jcacevedo    play      683
#              stop      528
# jhenao       stop      436
#              play      358
# jpalacio     play      256
#              stop      225
# jpatino      stop      377
#              play      355
# jzapata      play      432
#              stop      385
# ksolorza     play        2
#              stop        2
# lechavarria  stop       61
#              play       50
# lmejia       play      286
#              stop      224
# lsanchez     play        3
# lvelasquez   play      665
#              stop      539
# mmartinez    play      774
#              stop      580
# mquiroz      play       58
#              stop       56
# nserna       play      437
#              stop      316
# rsuarez      stop        1
# rvelasquez   play      585
#              stop      503
# Name: count, dtype: int64
# --------------------------------------------------
# seccion            estado
# Pegadora de Cajas  play      2371
#                    stop      2042
# Prensa             stop      4819
#                    play      4484
# Troquelado         play      3560
#                    stop      2939
# Name: count, dtype: int64
# --------------------------------------------------
# Dias de fabricación
# Inicio
# 950
# Fin
# 950
# --------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Conteo simple
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='estado', order=df['estado'].value_counts().index)
plt.title('Frecuencia de estados')
plt.xlabel('Estado')
plt.ylabel('Cantidad')
plt.show()

# %%
#Duracion total por usuario
# Sumar minutos por usuario
duracion_usuario = df.groupby('usuario')['duracion_min'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=duracion_usuario.values, y=duracion_usuario.index, palette='Blues_d')
plt.title('Duración total (min) por usuario')
plt.xlabel('Minutos totales')
plt.ylabel('Usuario')
plt.tight_layout()
plt.show()
print("-")
# Out:
# C:\Users\karen\AppData\Local\Temp\ipykernel_24348\3059294993.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=duracion_usuario.values, y=duracion_usuario.index, palette='Blues_d')
# -

# %%
duracion_seccion = df.groupby('seccion')['duracion_min'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=duracion_seccion.values, y=duracion_seccion.index, palette='Greens_d')
plt.title('Duración total (min) por sección')
plt.xlabel('Minutos totales')
plt.ylabel('Sección')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\karen\AppData\Local\Temp\ipykernel_24348\2817067950.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=duracion_seccion.values, y=duracion_seccion.index, palette='Greens_d')

# %%
# duracion promedio por sección
df.groupby('seccion')['duracion_min'].mean().sort_values(ascending=False)
# Out:
# seccion
# Troquelado           74.823873
# Pegadora de Cajas    74.593148
# Prensa               46.401919
# Name: duracion_min, dtype: float64

# %%
# Agrupado por día de inicio
uso_diario = df.groupby('dia_inicio')['duracion_min'].sum()

plt.figure(figsize=(12,6))
uso_diario.plot(marker='o')
plt.title('Duración total por día')
plt.xlabel('Día')
plt.ylabel('Minutos')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
np.mean(df.groupby('dia_inicio')['duracion_min'].sum())
# Out:
# 2566.1254320987655

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='estado', y='duracion_min')
plt.title('Distribución de duración por estado')
plt.xlabel('Estado')
plt.ylabel('Duración (min)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df, x='proceso', y='duracion_min', hue='estado')
plt.title('Distribución de duración por proceso y estado')
plt.xlabel('Proceso')
plt.ylabel('Duración (minutos)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df[df['estado']=='play'], x='proceso', y='fabricadas', hue='estado')
plt.title('Distribución de fabricación por proceso y estado')
plt.xlabel('Proceso')
plt.ylabel('Fabricadas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Eliminar outliers de fabricadas teniendo en cuenta el proceso
def quitar_outliers_por_proceso(grupo):
    q1 = grupo['fabricadas'].quantile(0.25)
    q3 = grupo['fabricadas'].quantile(0.75)
    iqr = q3 - q1
    li = q1 - 1.5 * iqr
    ls = q3 + 1.5 * iqr
    return grupo[(grupo['fabricadas'] >= li) & (grupo['fabricadas'] <= ls)]

# Separar datos
df_play = df[df['estado'] == 'play'].groupby('proceso', group_keys=False).apply(quitar_outliers_por_proceso)
df_rest = df[df['estado'] != 'play']

# Unirlos de nuevo
df = pd.concat([df_play, df_rest], ignore_index=True)

#Agregar un análisis para ver que usuarios cometieron más errores de digitación
# Contar errores de digitación por usuario
errores_digitacion = df[df['estado'] == 'play'].groupby('usuario')['fabricadas'].apply(lambda x: (x <= 0).sum()).reset_index()
errores_digitacion.columns = ['usuario', 'errores_digitacion']
# Ordenar por errores
errores_digitacion = errores_digitacion.sort_values(by='errores_digitacion', ascending=False)
# Mostrar los 10 usuarios con más errores de digitación
print("Usuarios con más errores de digitación:")
print(errores_digitacion.head(10))
# Out:
# Usuarios con más errores de digitación:
#         usuario  errores_digitacion
# 0     acalderon                   0
# 1       aflorez                   0
# 28       nserna                   0
# 27      mquiroz                   0
# 26    mmartinez                   0
# 25   lvelasquez                   0
# 24     lsanchez                   0
# 23       lmejia                   0
# 22  lechavarria                   0
# 21     ksolorza                   0
# C:\Users\karen\AppData\Local\Temp\ipykernel_24348\3750235251.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_play = df[df['estado'] == 'play'].groupby('proceso', group_keys=False).apply(quitar_outliers_por_proceso)

# %%
len(df)
# Out:
# 19212

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df[df['estado']=='play'], x='proceso', y='fabricadas', hue='estado')
plt.title('Distribución de fabricación por proceso y estado')
plt.xlabel('Proceso')
plt.ylabel('Fabricadas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Agrupar por proceso y sección
pivot = df.groupby(['proceso', 'seccion'])['duracion_min'].mean().unstack()

# Opcional: ordenar por duración total para mayor claridad
pivot = pivot.sort_values(by=pivot.columns.tolist(), ascending=False)

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))
sns.heatmap(pivot, annot=True, fmt=".1f", cmap='YlGnBu', linewidths=0.5, linecolor='gray')
plt.title('Duración promedio (min) por proceso y sección')
plt.xlabel('Sección')
plt.ylabel('Proceso')
plt.tight_layout()
plt.show()

# %%
df.head(10)
# Out:
#    pedido    op     referencia                                  maquina  \
# 0   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 1   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 2   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 3   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 4   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 5   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 6   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 7   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 8   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 9   27144  8318  PT-0000001327  MAQR700 - Maquina R700 6 color + barniz
#
#   seccion   proceso    usuario estado  fabricadas        fecha_inicio  \
# 0  Prensa  Barnizar  mmartinez   play         1.0 2023-08-01 09:39:49
# 1  Prensa  Barnizar  mmartinez   play     22760.0 2023-08-01 10:57:54
# 2  Prensa  Barnizar  mmartinez   play      7140.0 2023-08-01 15:48:37
# 3  Prensa  Barnizar    falzate   play     43000.0 2023-08-01 21:00:17
# 4  Prensa  Barnizar    falzate   play     20800.0 2023-08-02 00:00:00
# 5  Prensa  Barnizar  acalderon   play      7540.0 2023-08-02 01:06:32
# 6  Prensa  Barnizar  mmartinez   play      4580.0 2023-08-14 12:44:08
# 7  Prensa  Barnizar    falzate   play     45020.0 2023-08-14 19:31:49
# 8  Prensa  Barnizar  acalderon   play     50720.0 2023-08-15 02:04:16
# 9  Prensa  Barnizar  mmartinez   play      6810.0 2023-08-01 10:41:36
#
#             fecha_fin  duracion_sec  duracion_min  dia_inicio  hora_inicio  \
# 0 2023-08-01 10:41:27        3698.0         61.63  2023-08-01            9
# 1 2023-08-01 13:32:40        9286.0        154.77  2023-08-01           10
# 2 2023-08-01 16:35:00        2783.0         46.38  2023-08-01           15
# 3 2023-08-02 00:20:11       11994.0        199.90  2023-08-01           21
# 4 2023-08-02 01:00:11        3611.0         60.18  2023-08-02            0
# 5 2023-08-02 01:56:31        2999.0         49.98  2023-08-02            1
# 6 2023-08-14 13:27:34        2606.0         43.43  2023-08-14           12
# 7 2023-08-14 21:14:19        6150.0        102.50  2023-08-14           19
# 8 2023-08-15 05:12:18       11282.0        188.03  2023-08-15            2
# 9 2023-08-01 10:42:04          28.0          0.47  2023-08-01           10
#
#   dia_semana_inicio     dia_fin  hora_fin dia_semana_fin
# 0           Tuesday  2023-08-01        10        Tuesday
# 1           Tuesday  2023-08-01        13        Tuesday
# 2           Tuesday  2023-08-01        16        Tuesday
# 3           Tuesday  2023-08-02         0      Wednesday
# 4         Wednesday  2023-08-02         1      Wednesday
# 5         Wednesday  2023-08-02         1      Wednesday
# 6            Monday  2023-08-14        13         Monday
# 7            Monday  2023-08-14        21         Monday
# 8           Tuesday  2023-08-15         5        Tuesday
# 9           Tuesday  2023-08-01        10        Tuesday

# %%
print(df.columns)
# Out:
# Index(['pedido', 'op', 'referencia', 'maquina', 'seccion', 'proceso',
#        'usuario', 'estado', 'fabricadas', 'fecha_inicio', 'fecha_fin',
#        'duracion_sec', 'duracion_min', 'dia_inicio', 'hora_inicio',
#        'dia_semana_inicio', 'dia_fin', 'hora_fin', 'dia_semana_fin'],
#       dtype='object')

# %%
# Estadísticas básicas
print(df[['duracion_sec', 'duracion_min', 'fabricadas']].describe())

# Distribuciones
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['duracion_min', 'fabricadas']:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], bins=50, kde=True)
    plt.title(f'Distribución de {col}')
    plt.show()
# Out:
#        duracion_sec  duracion_min     fabricadas
# count  19212.000000  19212.000000   19212.000000
# mean    3482.690870     58.044896   14983.971976
# std     3208.286083     53.471381   26944.746828
# min        4.000000      0.070000       0.000000
# 25%     1259.000000     20.980000       0.000000
# 50%     2542.500000     42.375000       0.000000
# 75%     4663.500000     77.727500   18752.500000
# max    29969.000000    499.480000  240000.000000

# %%
sns.scatterplot(data=df, x='duracion_min', y='fabricadas')
plt.title('Duración vs. piezas fabricadas')
plt.xlabel('Duración (min)')
plt.ylabel('Fabricadas')
plt.grid(True)
plt.tight_layout()
plt.show()

# Correlación numérica
print(df[['duracion_min', 'duracion_sec', 'fabricadas']].corr())
# Out:
#               duracion_min  duracion_sec  fabricadas
# duracion_min      1.000000      1.000000    0.332695
# duracion_sec      1.000000      1.000000    0.332695
# fabricadas        0.332695      0.332695    1.000000

# %%
df.head(10)
# Out:
#    pedido    op     referencia                                  maquina  \
# 0   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 1   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 2   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 3   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 4   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 5   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 6   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 7   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 8   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 9   27144  8318  PT-0000001327  MAQR700 - Maquina R700 6 color + barniz
#
#   seccion   proceso    usuario estado  fabricadas        fecha_inicio  \
# 0  Prensa  Barnizar  mmartinez   play         1.0 2023-08-01 09:39:49
# 1  Prensa  Barnizar  mmartinez   play     22760.0 2023-08-01 10:57:54
# 2  Prensa  Barnizar  mmartinez   play      7140.0 2023-08-01 15:48:37
# 3  Prensa  Barnizar    falzate   play     43000.0 2023-08-01 21:00:17
# 4  Prensa  Barnizar    falzate   play     20800.0 2023-08-02 00:00:00
# 5  Prensa  Barnizar  acalderon   play      7540.0 2023-08-02 01:06:32
# 6  Prensa  Barnizar  mmartinez   play      4580.0 2023-08-14 12:44:08
# 7  Prensa  Barnizar    falzate   play     45020.0 2023-08-14 19:31:49
# 8  Prensa  Barnizar  acalderon   play     50720.0 2023-08-15 02:04:16
# 9  Prensa  Barnizar  mmartinez   play      6810.0 2023-08-01 10:41:36
#
#             fecha_fin  duracion_sec  duracion_min  dia_inicio  hora_inicio  \
# 0 2023-08-01 10:41:27        3698.0         61.63  2023-08-01            9
# 1 2023-08-01 13:32:40        9286.0        154.77  2023-08-01           10
# 2 2023-08-01 16:35:00        2783.0         46.38  2023-08-01           15
# 3 2023-08-02 00:20:11       11994.0        199.90  2023-08-01           21
# 4 2023-08-02 01:00:11        3611.0         60.18  2023-08-02            0
# 5 2023-08-02 01:56:31        2999.0         49.98  2023-08-02            1
# 6 2023-08-14 13:27:34        2606.0         43.43  2023-08-14           12
# 7 2023-08-14 21:14:19        6150.0        102.50  2023-08-14           19
# 8 2023-08-15 05:12:18       11282.0        188.03  2023-08-15            2
# 9 2023-08-01 10:42:04          28.0          0.47  2023-08-01           10
#
#   dia_semana_inicio     dia_fin  hora_fin dia_semana_fin
# 0           Tuesday  2023-08-01        10        Tuesday
# 1           Tuesday  2023-08-01        13        Tuesday
# 2           Tuesday  2023-08-01        16        Tuesday
# 3           Tuesday  2023-08-02         0      Wednesday
# 4         Wednesday  2023-08-02         1      Wednesday
# 5         Wednesday  2023-08-02         1      Wednesday
# 6            Monday  2023-08-14        13         Monday
# 7            Monday  2023-08-14        21         Monday
# 8           Tuesday  2023-08-15         5        Tuesday
# 9           Tuesday  2023-08-01        10        Tuesday

# %% [markdown]
# *Ingeniería de variables*

# %%
df_char = df.copy()

#Eficiencia por minuto
df_char['eficiencia_piezas_por_min'] = df_char.apply(
    lambda row: row['fabricadas'] / row['duracion_min']
    if row['estado'] == 'play' and row['duracion_min'] > 0 else np.nan, axis=1
)

# %%
#Pueden existir valores de eficiencia por fuera de los rangos, por lo que se eliminan
def filtrar_outliers_por_proceso(grupo):
    q1 = grupo['eficiencia_piezas_por_min'].quantile(0.25)
    q3 = grupo['eficiencia_piezas_por_min'].quantile(0.75)
    iqr = q3 - q1
    lim_sup = q3 + 1.5 * iqr
    return grupo[(grupo['eficiencia_piezas_por_min'] <= lim_sup) | grupo['eficiencia_piezas_por_min'].isna()]

# Aplicar solo sobre registros 'play'
df_filtrados = df_char[df_char['estado'] == 'play'].groupby('proceso', group_keys=False).apply(filtrar_outliers_por_proceso)
# Unir con los otros
df_char = pd.concat([df_filtrados, df_char[df_char['estado'] != 'play']], ignore_index=True)
# Out:
# C:\Users\karen\AppData\Local\Temp\ipykernel_24348\565925035.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_filtrados = df_char[df_char['estado'] == 'play'].groupby('proceso', group_keys=False).apply(filtrar_outliers_por_proceso)

# %%
# Clasificar el turno a partir de la hora
def clasificar_turno(hora):
    if 6 <= hora < 12:
        return 'Mañana'
    elif 12 <= hora < 21:   
        return 'Tarde'
    else:
        return 'Noche'

df_char['turno'] = df_char['hora_inicio'].apply(clasificar_turno)
orden_turnos = ['Mañana', 'Tarde', 'Noche']
df_char['turno'] = pd.Categorical(df_char['turno'], categories=orden_turnos, ordered=True)

# %%
df_play = df_char[df_char['estado'] == 'play']
df_play.head(10)
# Out:
#    pedido    op     referencia                                  maquina  \
# 0   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 1   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 2   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 3   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 4   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 5   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 6   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 7   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 8   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 9   27144  8318  PT-0000001327  MAQR700 - Maquina R700 6 color + barniz
#
#   seccion   proceso    usuario estado  fabricadas        fecha_inicio  ...  \
# 0  Prensa  Barnizar  mmartinez   play         1.0 2023-08-01 09:39:49  ...
# 1  Prensa  Barnizar  mmartinez   play     22760.0 2023-08-01 10:57:54  ...
# 2  Prensa  Barnizar  mmartinez   play      7140.0 2023-08-01 15:48:37  ...
# 3  Prensa  Barnizar    falzate   play     43000.0 2023-08-01 21:00:17  ...
# 4  Prensa  Barnizar    falzate   play     20800.0 2023-08-02 00:00:00  ...
# 5  Prensa  Barnizar  acalderon   play      7540.0 2023-08-02 01:06:32  ...
# 6  Prensa  Barnizar  mmartinez   play      4580.0 2023-08-14 12:44:08  ...
# 7  Prensa  Barnizar    falzate   play     45020.0 2023-08-14 19:31:49  ...
# 8  Prensa  Barnizar  acalderon   play     50720.0 2023-08-15 02:04:16  ...
# 9  Prensa  Barnizar  acalderon   play      6750.0 2023-08-02 04:37:46  ...
#
#   duracion_sec  duracion_min  dia_inicio hora_inicio  dia_semana_inicio  \
# 0       3698.0         61.63  2023-08-01           9            Tuesday
# 1       9286.0        154.77  2023-08-01          10            Tuesday
# 2       2783.0         46.38  2023-08-01          15            Tuesday
# 3      11994.0        199.90  2023-08-01          21            Tuesday
# 4       3611.0         60.18  2023-08-02           0          Wednesday
# 5       2999.0         49.98  2023-08-02           1          Wednesday
# 6       2606.0         43.43  2023-08-14          12             Monday
# 7       6150.0        102.50  2023-08-14          19             Monday
# 8      11282.0        188.03  2023-08-15           2            Tuesday
# 9       1016.0         16.93  2023-08-02           4          Wednesday
#
#       dia_fin hora_fin  dia_semana_fin eficiencia_piezas_por_min   turno
# 0  2023-08-01       10         Tuesday                  0.016226  Mañana
# 1  2023-08-01       13         Tuesday                147.056923  Mañana
# 2  2023-08-01       16         Tuesday                153.945666   Tarde
# 3  2023-08-02        0       Wednesday                215.107554   Noche
# 4  2023-08-02        1       Wednesday                345.629777   Noche
# 5  2023-08-02        1       Wednesday                150.860344   Noche
# 6  2023-08-14       13          Monday                105.457057   Tarde
# 7  2023-08-14       21          Monday                439.219512   Tarde
# 8  2023-08-15        5         Tuesday                269.744190   Noche
# 9  2023-08-02        4       Wednesday                398.700532   Noche
#
# [10 rows x 21 columns]

# %%
heatmap_sec_turno = df_char.pivot_table(
    index='seccion', columns='turno', values='eficiencia_piezas_por_min', aggfunc='mean')

plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_sec_turno, annot=True, fmt=".2f", cmap='YlGnBu')
plt.title('Eficiencia promedio por Sección y Turno')
plt.xlabel('Turno')
plt.ylabel('Sección')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\karen\AppData\Local\Temp\ipykernel_24348\2160758589.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   heatmap_sec_turno = df_char.pivot_table(

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(
    data=df_play,
    x='proceso',
    y='fabricadas',
    hue='turno'
)
plt.title('Piezas fabricadas por Proceso y Turno - Cuando está en Play')
plt.xlabel('Proceso')
plt.ylabel('Piezas totales')
plt.xticks(rotation=45)
plt.legend(title='Turno')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(
    data=df_play,
    x='proceso',
    y='eficiencia_piezas_por_min',
    hue='turno'
)
plt.title('Eficiencia por Proceso y Turno - Cuando está en Play')
plt.xlabel('Proceso')
plt.ylabel('Piezas fabricadas por minuto')
plt.xticks(rotation=45)
plt.legend(title='Turno')
plt.tight_layout()
plt.show()

# %%
usuarios_top = df_char[df_char['estado'] == 'play']['usuario'].value_counts().head(10).index

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df_char[(df_char['estado'] == 'play') & (df_char['usuario'].isin(usuarios_top))],
    x='usuario',
    y='eficiencia_piezas_por_min',
    hue='seccion'
)
plt.title('Productividad de Usuarios Top por Sección')
plt.xlabel('Usuario')
plt.ylabel('Piezas por minuto')
plt.xticks(rotation=45)
plt.legend(title='Sección')
plt.tight_layout()
plt.show()

# %%
df_char.head(10)
# Out:
#    pedido    op     referencia                                  maquina  \
# 0   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 1   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 2   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 3   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 4   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 5   27075  8235  PT-0000000388  MAQR700 - Maquina R700 6 color + barniz
# 6   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 7   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 8   27136  8311  PT-0000001497  MAQR700 - Maquina R700 6 color + barniz
# 9   27144  8318  PT-0000001327  MAQR700 - Maquina R700 6 color + barniz
#
#   seccion   proceso    usuario estado  fabricadas        fecha_inicio  ...  \
# 0  Prensa  Barnizar  mmartinez   play         1.0 2023-08-01 09:39:49  ...
# 1  Prensa  Barnizar  mmartinez   play     22760.0 2023-08-01 10:57:54  ...
# 2  Prensa  Barnizar  mmartinez   play      7140.0 2023-08-01 15:48:37  ...
# 3  Prensa  Barnizar    falzate   play     43000.0 2023-08-01 21:00:17  ...
# 4  Prensa  Barnizar    falzate   play     20800.0 2023-08-02 00:00:00  ...
# 5  Prensa  Barnizar  acalderon   play      7540.0 2023-08-02 01:06:32  ...
# 6  Prensa  Barnizar  mmartinez   play      4580.0 2023-08-14 12:44:08  ...
# 7  Prensa  Barnizar    falzate   play     45020.0 2023-08-14 19:31:49  ...
# 8  Prensa  Barnizar  acalderon   play     50720.0 2023-08-15 02:04:16  ...
# 9  Prensa  Barnizar  acalderon   play      6750.0 2023-08-02 04:37:46  ...
#
#   duracion_sec  duracion_min  dia_inicio hora_inicio  dia_semana_inicio  \
# 0       3698.0         61.63  2023-08-01           9            Tuesday
# 1       9286.0        154.77  2023-08-01          10            Tuesday
# 2       2783.0         46.38  2023-08-01          15            Tuesday
# 3      11994.0        199.90  2023-08-01          21            Tuesday
# 4       3611.0         60.18  2023-08-02           0          Wednesday
# 5       2999.0         49.98  2023-08-02           1          Wednesday
# 6       2606.0         43.43  2023-08-14          12             Monday
# 7       6150.0        102.50  2023-08-14          19             Monday
# 8      11282.0        188.03  2023-08-15           2            Tuesday
# 9       1016.0         16.93  2023-08-02           4          Wednesday
#
#       dia_fin hora_fin  dia_semana_fin eficiencia_piezas_por_min   turno
# 0  2023-08-01       10         Tuesday                  0.016226  Mañana
# 1  2023-08-01       13         Tuesday                147.056923  Mañana
# 2  2023-08-01       16         Tuesday                153.945666   Tarde
# 3  2023-08-02        0       Wednesday                215.107554   Noche
# 4  2023-08-02        1       Wednesday                345.629777   Noche
# 5  2023-08-02        1       Wednesday                150.860344   Noche
# 6  2023-08-14       13          Monday                105.457057   Tarde
# 7  2023-08-14       21          Monday                439.219512   Tarde
# 8  2023-08-15        5         Tuesday                269.744190   Noche
# 9  2023-08-02        4       Wednesday                398.700532   Noche
#
# [10 rows x 21 columns]

# %%
df_char.to_excel("data/BASE DE DATOS PCC_cleaned.xlsx", index=False)
print(df_char.columns)
# Out:
# Index(['pedido', 'op', 'referencia', 'maquina', 'seccion', 'proceso',
#        'usuario', 'estado', 'fabricadas', 'fecha_inicio', 'fecha_fin',
#        'duracion_sec', 'duracion_min', 'dia_inicio', 'hora_inicio',
#        'dia_semana_inicio', 'dia_fin', 'hora_fin', 'dia_semana_fin',
#        'eficiencia_piezas_por_min', 'turno'],
#       dtype='object')

# %%
len(df_char)
# Out:
# 18261
